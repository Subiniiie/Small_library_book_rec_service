# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

#서울
sum0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum0.csv', encoding='cp949')
sum6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum6.csv', encoding='cp949')
sum8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum8.csv', encoding='cp949')
sum14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum14.csv', encoding='cp949')
sum20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum20.csv', encoding='cp949')
sum30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum30.csv', encoding='cp949')
sum40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum40.csv', encoding='cp949')
sum50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum50.csv', encoding='cp949')
sum60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sum60.csv', encoding='cp949')
suw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw0.csv', encoding='cp949')
suw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw6.csv', encoding='cp949')
suw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw8.csv', encoding='cp949')
suw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw14.csv', encoding='cp949')
suw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw20.csv', encoding='cp949')
suw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw30.csv', encoding='cp949')
suw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw40.csv', encoding='cp949')
suw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw50.csv', encoding='cp949')
suw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw60.csv', encoding='cp949')

#부산
bsm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm0.csv', encoding='cp949')
bsm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm6.csv', encoding='cp949')
bsm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm8.csv', encoding='cp949')
bsm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm14.csv', encoding='cp949')
bsm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm20.csv', encoding='cp949')
bsm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm30.csv', encoding='cp949')
bsm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm40.csv', encoding='cp949')
bsm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm50.csv', encoding='cp949')
bsm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsm60.csv', encoding='cp949')
bsw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw0.csv', encoding='cp949')
bsw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw6.csv', encoding='cp949')
bsw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw8.csv', encoding='cp949')
bsw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw14.csv', encoding='cp949')
bsw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw20.csv', encoding='cp949')
bsw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw30.csv', encoding='cp949')
bsw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw40.csv', encoding='cp949')
bsw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw50.csv', encoding='cp949')
bsw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/bsw60.csv', encoding='cp949')

#광주
gjm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm0.csv', encoding='cp949')
gjm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm6.csv', encoding='cp949')
gjm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm8.csv', encoding='cp949')
gjm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm14.csv', encoding='cp949')
gjm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm20.csv', encoding='cp949')
gjm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm30.csv', encoding='cp949')
gjm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm40.csv', encoding='cp949')
gjm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm50.csv', encoding='cp949')
gjm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjm60.csv', encoding='cp949')
gjw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw0.csv', encoding='cp949')
gjw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw6.csv', encoding='cp949')
gjw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw8.csv', encoding='cp949')
gjw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw14.csv', encoding='cp949')
gjw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw20.csv', encoding='cp949')
gjw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw30.csv', encoding='cp949')
gjw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw40.csv', encoding='cp949')
gjw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw50.csv', encoding='cp949')
gjw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/gjw60.csv', encoding='cp949')

#대전
djm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm0.csv', encoding='cp949')
djm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm6.csv', encoding='cp949')
djm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm8.csv', encoding='cp949')
djm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm14.csv', encoding='cp949')
djm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm20.csv', encoding='cp949')
djm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm30.csv', encoding='cp949')
djm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm40.csv', encoding='cp949')
djm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm50.csv', encoding='cp949')
djm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djm60.csv', encoding='cp949')
djw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw0.csv', encoding='cp949')
djw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw6.csv', encoding='cp949')
djw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw8.csv', encoding='cp949')
djw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw14.csv', encoding='cp949')
djw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw20.csv', encoding='cp949')
djw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw30.csv', encoding='cp949')
djw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw40.csv', encoding='cp949')
djw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw50.csv', encoding='cp949')
djw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/djw60.csv', encoding='cp949')

#대구
dgm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm0.csv', encoding='cp949')
dgm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm6.csv', encoding='cp949')
dgm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm8.csv', encoding='cp949')
dgm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm14.csv', encoding='cp949')
dgm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm20.csv', encoding='cp949')
dgm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm30.csv', encoding='cp949')
dgm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm40.csv', encoding='cp949')
dgm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm50.csv', encoding='cp949')
dgm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgm60.csv', encoding='cp949')
dgw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw0.csv', encoding='cp949')
dgw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw6.csv', encoding='cp949')
dgw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw8.csv', encoding='cp949')
dgw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw14.csv', encoding='cp949')
dgw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw20.csv', encoding='cp949')
dgw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw30.csv', encoding='cp949')
dgw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw40.csv', encoding='cp949')
dgw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw50.csv', encoding='cp949')
dgw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/dgw60.csv', encoding='cp949')

#울산
usm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm0.csv', encoding='cp949')
usm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm6.csv', encoding='cp949')
usm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm8.csv', encoding='cp949')
usm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm14.csv', encoding='cp949')
usm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm20.csv', encoding='cp949')
usm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm30.csv', encoding='cp949')
usm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm40.csv', encoding='cp949')
usm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm50.csv', encoding='cp949')
usm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usm60.csv', encoding='cp949')
usw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw0.csv', encoding='cp949')
usw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw6.csv', encoding='cp949')
usw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw8.csv', encoding='cp949')
usw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw14.csv', encoding='cp949')
usw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw20.csv', encoding='cp949')
usw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw30.csv', encoding='cp949')
usw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw40.csv', encoding='cp949')
usw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw50.csv', encoding='cp949')
usw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/usw60.csv', encoding='cp949')

#인천
icm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm0.csv', encoding='cp949')
icm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm6.csv', encoding='cp949')
icm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm8.csv', encoding='cp949')
icm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm14.csv', encoding='cp949')
icm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm20.csv', encoding='cp949')
icm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm30.csv', encoding='cp949')
icm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm40.csv', encoding='cp949')
icm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm50.csv', encoding='cp949')
icm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icm60.csv', encoding='cp949')
icw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw0.csv', encoding='cp949')
icw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw6.csv', encoding='cp949')
icw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw8.csv', encoding='cp949')
icw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw14.csv', encoding='cp949')
icw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw20.csv', encoding='cp949')
icw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw30.csv', encoding='cp949')
icw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw40.csv', encoding='cp949')
icw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw50.csv', encoding='cp949')
icw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/icw60.csv', encoding='cp949')

#세종
sjm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm0.csv', encoding='cp949')
sjm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm6.csv', encoding='cp949')
sjm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm8.csv', encoding='cp949')
sjm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm14.csv', encoding='cp949')
sjm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm20.csv', encoding='cp949')
sjm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm30.csv', encoding='cp949')
sjm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm40.csv', encoding='cp949')
sjm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm50.csv', encoding='cp949')
sjm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjm60.csv', encoding='cp949')
sjw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw0.csv', encoding='cp949')
sjw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw6.csv', encoding='cp949')
sjw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw8.csv', encoding='cp949')
sjw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw14.csv', encoding='cp949')
sjw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw20.csv', encoding='cp949')
sjw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw30.csv', encoding='cp949')
sjw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw40.csv', encoding='cp949')
sjw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/sjw50.csv', encoding='cp949')
sjw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/suw60.csv', encoding='cp949')

#제주
jjm0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm0.csv', encoding='cp949')
jjm6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm6.csv', encoding='cp949')
jjm8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm8.csv', encoding='cp949')
jjm14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm14.csv', encoding='cp949')
jjm20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm20.csv', encoding='cp949')
jjm30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm30.csv', encoding='cp949')
jjm40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm40.csv', encoding='cp949')
jjm50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm50.csv', encoding='cp949')
jjm60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjm60.csv', encoding='cp949')
jjw0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw0.csv', encoding='cp949')
jjw6 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw6.csv', encoding='cp949')
jjw8 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw8.csv', encoding='cp949')
jjw14 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw14.csv', encoding='cp949')
jjw20 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw20.csv', encoding='cp949')
jjw30 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw30.csv', encoding='cp949')
jjw40 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw40.csv', encoding='cp949')
jjw50 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw50.csv', encoding='cp949')
jjw60 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/공모전/빅데이터 활용 미래 사회문제 해결 아이디어 공모전/작은 도서관 운영 방안 추천/데이터/대출/jjw60.csv', encoding='cp949')

# %%
loan = pd.concat([sum0, sum6, sum8, sum14, sum20, sum30, sum40, sum50, sum60,
                            suw0, suw6, suw8, suw14, suw20, suw30, suw40, suw50, suw60,
                  bsm0, bsm6, bsm8, bsm14, bsm20, bsm30, bsm40, bsm50, bsm60,
                            bsw0, bsw6, bsw8, bsw14, bsw20, bsw30, bsw40, bsw50, bsw60,
                  gjm0, gjm6, gjm8, gjm14, gjm20, gjm30, gjm40, gjm50, gjm60,
                            gjw0, gjw6, gjw8, gjw14, gjw20, gjw30, gjw40, gjw50, gjw60,
                  djm0, djm6, djm8, djm14, djm20, djm30, djm40, djm50, djm60,
                            djw0, djw6, djw8, djw14, djw20, djw30, djw40, djw50, djw60,
                  dgm0, dgm6, dgm8, dgm14, dgm20, dgm30, dgm40, dgm50, dgm60,
                            dgw0, dgw6, dgw8, dgw14, dgw20, dgw30, dgw40, dgw50, dgw60,
                  usm0, usm6, usm8, usm14, usm20, usm30, usm40, usm50, usm60,
                            usw0, usw6, usw8, usw14, usw20, usw30, usw40, usw50, usw60,
                  icm0, icm6, icm8, icm14, icm20, icm30, icm40, icm50, icm60,
                            icw0, icw6, icw8, icw14, icw20, icw30, icw40, icw50, icw60,
                  sjm0, sjm6, sjm8, sjm14, sjm20, sjm30, sjm40, sjm50, sjm60,
                            sjw0, sjw6, sjw8, sjw14, sjw20, sjw30, sjw40, sjw50, sjw60,
                  jjm0, jjm6, jjm8, jjm14, jjm20, jjm30, jjm40, jjm50, jjm60,
                            jjw0, jjw6, jjw8, jjw14, jjw20, jjw30, jjw40, jjw50, jjw60
                 ])

# %%
loan
# Out:
#       순위                        서명                       저자   출판사  출판년도    권  \
# 0      1          수박 수영장 :안녕달 그림책                  지은이: 안녕달    창비  2015  NaN
# 1      2              숲속 100층짜리 집     글·그림: 이와이 도시오 ;옮김: 김숙   북뱅크  2021  NaN
# 2      3                   당근 유치원                  지은이: 안녕달    창비  2020  NaN
# 3      4                 오싹오싹 팬티!       글: 에런 레이놀즈 ;옮김: 홍연미   토토북  2018  NaN
# 4      5                    고구마구마                  지은이: 사이다    반달  2017  NaN
# ..   ...                       ...                      ...   ...   ...  ...
# 195  164                   랄랄라 하우스                   김영하 지음  마음산책  2005  NaN
# 196  164                가면산장 살인사건   지은이: 히가시노 게이고 ;옮긴이: 김난주    재인  2014  NaN
# 197  164        너의 하늘을 보아 :박노해 시집                  지은이: 박노해  느린걸음  2022  NaN
# 198  164    (다윈의 안경으로 본) 인간동물 관찰기         마크 넬리슨 지음 ;최진영 옮김  푸른지식  2014  NaN
# 199  164  레슨 인 케미스트리 :보니 가머스 장편소설     지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  2022    1
#
# ...

# %%
loan = loan.reset_index()

# %%
loan.drop(['index', '순위', '출판년도', '권'], axis = 1, inplace=True)

# %%
loan
# Out:
#                              서명                       저자   출판사  \
# 0              수박 수영장 :안녕달 그림책                  지은이: 안녕달    창비
# 1                  숲속 100층짜리 집     글·그림: 이와이 도시오 ;옮김: 김숙   북뱅크
# 2                       당근 유치원                  지은이: 안녕달    창비
# 3                     오싹오싹 팬티!       글: 에런 레이놀즈 ;옮김: 홍연미   토토북
# 4                        고구마구마                  지은이: 사이다    반달
# ...                         ...                      ...   ...
# 32395                   랄랄라 하우스                   김영하 지음  마음산책
# 32396                가면산장 살인사건   지은이: 히가시노 게이고 ;옮긴이: 김난주    재인
# 32397        너의 하늘을 보아 :박노해 시집                  지은이: 박노해  느린걸음
# 32398    (다윈의 안경으로 본) 인간동물 관찰기         마크 넬리슨 지음 ;최진영 옮김  푸른지식
# 32399  레슨 인 케미스트리 :보니 가머스 장편소설     지은이: 보니 가머스 ;옮긴이: 심연희  다산북스
#
#                    ISBN  ISBN부가기호  KDC 대출건수  성별         연령  지역
# 0     9,788,940,000,000    77,810  814  164  남자  영유아(0~5세)  서울
# 1     9,788,970,000,000    74,830  834  137  남자  영유아(0~5세)  서울
# ...

# %%
import pandas as pd

#지수표현식 없애기
pd.options.display.float_format = '{:.5f}'.format
# float 형 -> 소숫점 제거
pd.set_option('display.float_format', '{:,.0f}'.format)

loan['KDC'] = loan['KDC'].apply(lambda x: (x // 100) * 100)

# %%
loan
# Out:
#                              서명                       저자   출판사  \
# 0              수박 수영장 :안녕달 그림책                  지은이: 안녕달    창비
# 1                  숲속 100층짜리 집     글·그림: 이와이 도시오 ;옮김: 김숙   북뱅크
# 2                       당근 유치원                  지은이: 안녕달    창비
# 3                     오싹오싹 팬티!       글: 에런 레이놀즈 ;옮김: 홍연미   토토북
# 4                        고구마구마                  지은이: 사이다    반달
# ...                         ...                      ...   ...
# 32395                   랄랄라 하우스                   김영하 지음  마음산책
# 32396                가면산장 살인사건   지은이: 히가시노 게이고 ;옮긴이: 김난주    재인
# 32397        너의 하늘을 보아 :박노해 시집                  지은이: 박노해  느린걸음
# 32398    (다윈의 안경으로 본) 인간동물 관찰기         마크 넬리슨 지음 ;최진영 옮김  푸른지식
# 32399  레슨 인 케미스트리 :보니 가머스 장편소설     지은이: 보니 가머스 ;옮긴이: 심연희  다산북스
#
#                    ISBN  ISBN부가기호  KDC 대출건수  성별         연령  지역
# 0     9,788,940,000,000    77,810  800  164  남자  영유아(0~5세)  서울
# 1     9,788,970,000,000    74,830  800  137  남자  영유아(0~5세)  서울
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32400 entries, 0 to 32399
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   서명        32400 non-null  object
#  1   저자        32400 non-null  object
#  2   출판사       32220 non-null  object
#  3   ISBN      32397 non-null  float64
#  4   ISBN부가기호  31507 non-null  float64
#  5   KDC       31644 non-null  float64
#  6   대출건수      32400 non-null  object
#  7   성별        32398 non-null  object
#  8   연령        32398 non-null  object
#  9   지역        32398 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 2.5+ MB

# %%
loan.isna().sum()
# Out:
# 서명            0
# 저자            0
# 출판사         180
# ISBN          3
# ISBN부가기호    893
# KDC         756
# 대출건수          0
# 성별            2
# 연령            2
# 지역            2
# dtype: int64

# %%
loan = loan.loc[loan['출판사'].notnull()] #결측치 제거
loan = loan.loc[loan['ISBN'].notnull()] #결측치 제거
loan = loan.loc[loan['ISBN부가기호'].notnull()] #결측치 제거
loan = loan.loc[loan['KDC'].notnull()] #결측치 제거
loan = loan.loc[loan['성별'].notnull()] #결측치 제거
loan = loan.loc[loan['연령'].notnull()] #결측치 제거
loan = loan.loc[loan['지역'].notnull()] #결측치 제거

# %%
loan.isna().sum()
# Out:
# 서명          0
# 저자          0
# 출판사         0
# ISBN        0
# ISBN부가기호    0
# KDC         0
# 대출건수        0
# 성별          0
# 연령          0
# 지역          0
# dtype: int64

# %%
loan['대출건수'] = loan['대출건수'].astype(str)
loan['ISBN'] = loan['ISBN'].astype(str)
loan['ISBN부가기호'] = loan['ISBN부가기호'].astype(str)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31313 entries, 0 to 32399
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   서명        31313 non-null  object
#  1   저자        31313 non-null  object
#  2   출판사       31313 non-null  object
#  3   ISBN      31313 non-null  object
#  4   ISBN부가기호  31313 non-null  object
#  5   KDC       31313 non-null  float64
#  6   대출건수      31313 non-null  object
#  7   성별        31313 non-null  object
#  8   연령        31313 non-null  object
#  9   지역        31313 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 2.6+ MB

# %%
# 콤마가 있는 값을 제거하는 함수
def remove_comma(value):
    if ',' in value:  # 값에 콤마가 있는지 확인
        return value.replace(',', '')  # 콤마가 있으면 제거
    else:
        return value  # 콤마가 없으면 그대로 반환

# 콤마 제거
loan['대출건수'] = loan['대출건수'].apply(remove_comma)
loan['ISBN'] = loan['ISBN'].apply(remove_comma)
loan['ISBN부가기호'] = loan['ISBN부가기호'].apply(remove_comma)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31313 entries, 0 to 32399
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   서명        31313 non-null  object
#  1   저자        31313 non-null  object
#  2   출판사       31313 non-null  object
#  3   ISBN      31313 non-null  object
#  4   ISBN부가기호  31313 non-null  object
#  5   KDC       31313 non-null  float64
#  6   대출건수      31313 non-null  object
#  7   성별        31313 non-null  object
#  8   연령        31313 non-null  object
#  9   지역        31313 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 2.6+ MB

# %%
loan['대출건수'] = loan['대출건수'].astype(str)
loan['대출건수'] = loan['대출건수'].astype(str)
loan['대출건수'] = loan['대출건수'].astype(str)

# %%
loan
# Out:
#                              서명                       저자   출판사  \
# 0              수박 수영장 :안녕달 그림책                  지은이: 안녕달    창비
# 1                  숲속 100층짜리 집     글·그림: 이와이 도시오 ;옮김: 김숙   북뱅크
# 2                       당근 유치원                  지은이: 안녕달    창비
# 3                     오싹오싹 팬티!       글: 에런 레이놀즈 ;옮김: 홍연미   토토북
# 4                        고구마구마                  지은이: 사이다    반달
# ...                         ...                      ...   ...
# 32395                   랄랄라 하우스                   김영하 지음  마음산책
# 32396                가면산장 살인사건   지은이: 히가시노 게이고 ;옮긴이: 김난주    재인
# 32397        너의 하늘을 보아 :박노해 시집                  지은이: 박노해  느린걸음
# 32398    (다윈의 안경으로 본) 인간동물 관찰기         마크 넬리슨 지음 ;최진영 옮김  푸른지식
# 32399  레슨 인 케미스트리 :보니 가머스 장편소설     지은이: 보니 가머스 ;옮긴이: 심연희  다산북스
#
#                   ISBN ISBN부가기호  KDC 대출건수  성별         연령  지역
# 0      9788940000000.0  77810.0  800  164  남자  영유아(0~5세)  서울
# 1      9788970000000.0  74830.0  800  137  남자  영유아(0~5세)  서울
# ...

# %%
loan['대출건수'] = loan['대출건수'].astype(float)
loan['ISBN'] = loan['ISBN'].astype(float)
loan['ISBN부가기호'] = loan['ISBN부가기호'].astype(float)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31313 entries, 0 to 32399
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   서명        31313 non-null  object
#  1   저자        31313 non-null  object
#  2   출판사       31313 non-null  object
#  3   ISBN      31313 non-null  float64
#  4   ISBN부가기호  31313 non-null  float64
#  5   KDC       31313 non-null  float64
#  6   대출건수      31313 non-null  float64
#  7   성별        31313 non-null  object
#  8   연령        31313 non-null  object
#  9   지역        31313 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 2.6+ MB

# %%
loan['대출건수'] = loan['대출건수'].astype(int)
loan['ISBN'] = loan['ISBN'].astype(int)
loan['ISBN부가기호'] = loan['ISBN부가기호'].astype(int)

# %%
loan['대출건수'] = loan['대출건수'].astype(int)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31313 entries, 0 to 32399
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   서명        31313 non-null  object
#  1   저자        31313 non-null  object
#  2   출판사       31313 non-null  object
#  3   ISBN      31313 non-null  object
#  4   ISBN부가기호  31313 non-null  object
#  5   KDC       31313 non-null  object
#  6   대출건수      31313 non-null  int64
#  7   성별        31313 non-null  object
#  8   연령        31313 non-null  object
#  9   지역        31313 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.6+ MB

# %%
loan
# Out:
#                              서명                       저자   출판사           ISBN  \
# 0              수박 수영장 :안녕달 그림책                  지은이: 안녕달    창비  9788940000000
# 1                  숲속 100층짜리 집     글·그림: 이와이 도시오 ;옮김: 김숙   북뱅크  9788970000000
# 2                       당근 유치원                  지은이: 안녕달    창비  9788940000000
# 3                     오싹오싹 팬티!       글: 에런 레이놀즈 ;옮김: 홍연미   토토북  9788960000000
# 4                        고구마구마                  지은이: 사이다    반달  9788960000000
# ...                         ...                      ...   ...            ...
# 32395                   랄랄라 하우스                   김영하 지음  마음산책  9788990000000
# 32396                가면산장 살인사건   지은이: 히가시노 게이고 ;옮긴이: 김난주    재인  9788990000000
# 32397        너의 하늘을 보아 :박노해 시집                  지은이: 박노해  느린걸음  9788990000000
# 32398    (다윈의 안경으로 본) 인간동물 관찰기         마크 넬리슨 지음 ;최진영 옮김  푸른지식  9789000000000
# 32399  레슨 인 케미스트리 :보니 가머스 장편소설     지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
#
# ...

# %%
new_rows = []  # 새로운 행을 저장할 리스트 생성

for index, row in loan.iterrows():
    loan_value = row['대출건수']
    for i in range(loan_value):
        new_rows.append(row.copy())  # '대출건수' 열의 값만큼 행을 복사하여 리스트에 추가

# 새로운 행을 데이터프레임에 추가
loan = loan.append(new_rows, ignore_index=True)
# Out:
# <ipython-input-68-b950c847473a>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   loan = loan.append(new_rows, ignore_index=True)

# %%
loan.tail(500)
# Out:
#                                서명                     저자   출판사           ISBN  \
# 2229014           완벽한 생애 :조해진 소설                지은이: 조해진    창비  9788940000000
# 2229015           완벽한 생애 :조해진 소설                지은이: 조해진    창비  9788940000000
# 2229016           완벽한 생애 :조해진 소설                지은이: 조해진    창비  9788940000000
# 2229017           완벽한 생애 :조해진 소설                지은이: 조해진    창비  9788940000000
# 2229018           완벽한 생애 :조해진 소설                지은이: 조해진    창비  9788940000000
# ...                           ...                    ...   ...            ...
# 2229509  레슨 인 케미스트리 :보니 가머스 장편소설   지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
# 2229510  레슨 인 케미스트리 :보니 가머스 장편소설   지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
# 2229511  레슨 인 케미스트리 :보니 가머스 장편소설   지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
# 2229512  레슨 인 케미스트리 :보니 가머스 장편소설   지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
# 2229513  레슨 인 케미스트리 :보니 가머스 장편소설   지은이: 보니 가머스 ;옮긴이: 심연희  다산북스  9791130000000
#
# ...

# %%
loan.drop(['대출건수'], axis = 1, inplace=True)

# %%
#폰트 설치
# 필요 라이브러리 불러오기
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import os

# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum

fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설정

# %%
#라벨 인코딩
#문자형 변수를 숫자형 범수로

# %%
object_features = loan[['서명','저자','출판사', 'ISBN', 'ISBN부가기호', 'KDC', '성별','연령','지역']]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
for f in object_features:
    labels = []
    le = LabelEncoder()
    items = list(loan[f])
    le.fit(items)
    labels = le.transform(items)
    loan[f] = labels

# %%
loan
# Out:
#            서명    저자  출판사  ISBN  ISBN부가기호  KDC  성별  연령  지역
# 0        2665  2931  843     6       288    8   0   5   4
# 1        2718   628  443     9       256    8   0   5   4
# 2        1582  2931  843     6       288    8   0   5   4
# 3        3281   357  922     8       291    8   0   5   4
# 4         804  2886  387     8       288    8   0   5   4
# ...       ...   ...  ...   ...       ...  ...  ..  ..  ..
# 2229509  1801  2872  219    15        92    8   1   4   8
# 2229510  1801  2872  219    15        92    8   1   4   8
# 2229511  1801  2872  219    15        92    8   1   4   8
# 2229512  1801  2872  219    15        92    8   1   4   8
# 2229513  1801  2872  219    15        92    8   1   4   8
#
# [2229514 rows x 9 columns]

# %%
loan.drop(['서명'], axis = 1, inplace=True)
loan.drop(['저자'], axis = 1, inplace=True)
loan.drop(['출판사'], axis = 1, inplace=True)
loan.drop(['ISBN부가기호'], axis = 1, inplace=True)

# %%
corr = loan.corr()
corr = loan.agg('corr')
corr = loan[['ISBN', 'KDC','성별','연령','지역']].corr()
corr = loan[['ISBN', 'KDC','성별','연령','지역']].agg('corr')
print(corr)
# Out:
#       ISBN  KDC  성별  연령  지역
# ISBN     1   -0  -0  -0  -0
# KDC     -0    1   0   0  -0
# 성별      -0    0   1  -0   0
# 연령      -0    0  -0   1  -0
# 지역      -0   -0   0  -0   1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('pastel')

plt.figure(figsize=(10,8))
corr = loan.corr(method = 'pearson')
sns.heatmap(corr,cmap='bwr',annot=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# loan은 DataFrame 변수라고 가정합니다.

# 숫자형 변수들만 선택하여 새로운 DataFrame 생성
numeric_columns = loan.select_dtypes(include='number')
# 산점도 행렬 그리기
sns.pairplot(numeric_columns)
plt.show()

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280579 entries, 0 to 2280578
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   서명      int64
#  1   저자      int64
#  2   출판사     int64
#  3   성별      int64
#  4   연령      int64
#  5   지역      int64
# dtypes: int64(6)
# memory usage: 104.4 MB
